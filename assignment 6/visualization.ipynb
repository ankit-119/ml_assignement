# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('weather.csv')

# %%
data=pd.read_csv("weather.csv")
data=data.dropna()

# %%
data.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
# 3       1005.5       1007.0         2         7     13.5     14.1        Yes
# 4       1018.3       1018.5         7         7     11.1     15.4        Yes
#
#    RISK_MM  RainTomorrow
# 0      3.6           Yes
# 1      3.6           Yes
# 2     39.8           Yes
# 3      2.8           Yes
# 4      0.0            No
#
# [5 rows x 24 columns]

# %%
data.shape
# Out:
# (328, 24)

# %%
data.describe(include='all')
# Out:
#               Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count          328       328  328.000000  328.000000  328.000000   328.000000
# unique         328         1         NaN         NaN         NaN          NaN
# top     12/27/2007  Canberra         NaN         NaN         NaN          NaN
# freq             1       328         NaN         NaN         NaN          NaN
# mean           NaN       NaN    7.742988   20.897561    1.440854     4.702439
# std            NaN       NaN    5.945199    6.707310    4.289427     2.681183
# min            NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%            NaN       NaN    2.850000   15.500000    0.000000     2.550000
# 50%            NaN       NaN    7.900000   20.400000    0.000000     4.400000
# 75%            NaN       NaN   12.800000   25.800000    0.200000     6.600000
# max            NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
#           Sunshine WindGustDir  WindGustSpeed WindDir9am      ...       \
# count   328.000000         328     328.000000        328      ...
# unique         NaN          16            NaN         16      ...
# top            NaN          NW            NaN         SE      ...
# freq           NaN          64            NaN         47      ...
# mean      8.014939         NaN      40.396341        NaN      ...
# std       3.506646         NaN      13.132176        NaN      ...
# min       0.000000         NaN      13.000000        NaN      ...
# 25%       6.000000         NaN      31.000000        NaN      ...
# 50%       8.750000         NaN      39.000000        NaN      ...
# 75%      10.700000         NaN      46.000000        NaN      ...
# max      13.600000         NaN      98.000000        NaN      ...
#
#        Humidity3pm  Pressure9am  Pressure3pm    Cloud9am    Cloud3pm  \
# count   328.000000   328.000000   328.000000  328.000000  328.000000
# unique         NaN          NaN          NaN         NaN         NaN
# top            NaN          NaN          NaN         NaN         NaN
# freq           NaN          NaN          NaN         NaN         NaN
# mean     44.003049  1019.350000  1016.530793    3.905488    4.000000
# std      16.605975     6.715244     6.469774    2.974957    2.652101
# min      13.000000   996.500000   996.800000    0.000000    0.000000
# 25%      32.000000  1014.800000  1012.400000    1.000000    1.000000
# 50%      42.500000  1019.750000  1016.900000    4.000000    4.000000
# 75%      54.000000  1024.300000  1021.125000    7.000000    7.000000
# max      93.000000  1035.700000  1033.200000    8.000000    8.000000
#
#            Temp9am     Temp3pm  RainToday     RISK_MM  RainTomorrow
# count   328.000000  328.000000        328  328.000000           328
# unique         NaN         NaN          2         NaN             2
# top            NaN         NaN         No         NaN            No
# freq           NaN         NaN        267         NaN           268
# mean     12.815549   19.556402        NaN    1.422561           NaN
# std       5.542521    6.644311        NaN    4.234023           NaN
# min       0.100000    5.100000        NaN    0.000000           NaN
# 25%       8.175000   14.500000        NaN    0.000000           NaN
# 50%      13.500000   18.850000        NaN    0.000000           NaN
# 75%      17.200000   24.225000        NaN    0.200000           NaN
# max      24.700000   34.500000        NaN   39.800000           NaN
#
# [11 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
j=0
for i in data.columns:
    if(data[i].dtypes!=object):
        plt.figure(j)
        sns.distplot(data[i],rug=True)
        j+=1
